# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynald20/Malaria-Cells-Image-Recognition/blob/master/Malaria_Cell_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MALARIA CELLS IMAGE RECOGNITION**
#
# Classification of Malaria Cells Identification in Red Blood Cells Using Tensorflow

# %% [markdown]
# **Group Members:**
# 1. Raynald Masli
# 2. Syifa Nurul Fatimah

# %% [markdown]
# ## **Import Packages**

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2

# %% [markdown]
# ## **Download Data from Kaggle**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-9b90313a-11b8-4c42-9e5d-571054843442" name="files[]" multiple disabled />
#      <output id="result-9b90313a-11b8-4c42-9e5d-571054843442">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle (1).json
# {'kaggle.json': b'{"username":"raynaldmasli","key":"f0b16ad96cd92fe3c64f0b6430d2907b"}'}

# %%
# !ls -lha kaggle.json #Make sure that kaggle.json has already upload
# Out:
# -rw-r--r-- 1 root root 68 Mar 28 09:31 kaggle.json

# %%
# !pip install -q kaggle

# %%
#Access the Kaggle dataset for data input
# !mkdir -p~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# Out:
# mkdir: invalid option -- '~'
# Try 'mkdir --help' for more information.
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                            title                                                size  lastUpdated          downloadCount
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# unanimad/dataisbeautiful                                       Reddit - Data is Beautiful                           11MB  2020-03-21 22:28:28           1172
# allen-institute-for-ai/CORD-19-research-challenge              COVID-19 Open Research Dataset Challenge (CORD-19)  729MB  2020-03-27 23:46:53          33900
# rubenssjr/brasilian-houses-to-rent                             brazilian_houses_to_rent                            282KB  2020-03-25 22:51:17           1103
# charlieharper/spatial-data-for-cord19-covid19-ordc             Spatial Data for CORD-19 (COVID-19 ORDC)            136MB  2020-03-24 20:17:09            139
# clmentbisaillon/fake-and-real-news-dataset                     Fake and real news dataset                           41MB  2020-03-26 18:51:15            136
# paultimothymooney/covid19-containment-and-mitigation-measures  COVID-19 containment and mitigation measures         91KB  2020-03-27 13:52:04            311
# skylord/coronawhy                                              CoronaWhy                                           588MB  2020-03-28 14:33:01             36
# sudalairajkumar/novel-corona-virus-2019-dataset                Novel Corona Virus 2019 Dataset                     394KB  2020-03-28 06:37:32          89344
# kimjihoo/coronavirusdataset                                    Data Science for COVID-19 (DS4C)                      3MB  2020-03-22 04:17:54          21961
# jessemostipak/hotel-booking-demand                             Hotel booking demand                                  1MB  2020-02-13 01:27:20          11129
# shivamb/real-or-fake-fake-jobposting-prediction                [Real or Fake] Fake JobPosting Prediction            16MB  2020-02-29 08:23:34           2311
# brunotly/foreign-exchange-rates-per-dollar-20002019            Foreign Exchange Rates 2000-2019                      1MB  2020-03-03 17:43:07           1878
# timoboz/data-science-cheat-sheets                              Data Science Cheat Sheets                           596MB  2020-02-04 19:42:27           6910
# imdevskp/sars-outbreak-2003-complete-dataset                   SARS 2003 Outbreak Complete Dataset                  10KB  2020-02-26 10:25:22           2305
# imdevskp/ebola-outbreak-20142016-complete-dataset              Ebola 2014-2016 Outbreak Complete Dataset           101KB  2020-02-26 14:36:31           2109
# tunguz/big-five-personality-test                               Big Five Personality Test                           159MB  2020-02-17 15:59:37           3375
# paultimothymooney/coronavirus-genome-sequence                  Coronavirus Genome Sequence                           9MB  2020-02-29 00:25:13            722
# arindam235/startup-investments-crunchbase                      StartUp Investments (Crunchbase)                      3MB  2020-02-17 21:54:42           2357
# timoboz/tesla-stock-data-from-2010-to-2020                     Tesla stock data from 2010 to 2020                   46KB  2020-02-04 17:15:32           3232
# timoboz/python-data-science-handbook                           Python Data Science Handbook                         15MB  2020-02-04 18:27:14           1581

# %%
# !kaggle datasets download -d iarunava/cell-images-for-detecting-malaria #malaria-cells-images download from Kaggle
# Out:
# cell-images-for-detecting-malaria.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ## **Data Preparation**

# %%
import zipfile

#Extract the file from zip file
images = zipfile.ZipFile("/content/cell-images-for-detecting-malaria.zip", 'r')
images.extractall("/content")
images.close()

# %%
#Assign the images into either the infected cells and uninfected cells 

infected_cells = os.listdir("/content/cell_images/Parasitized")
uninfected_cells = os.listdir("/content/cell_images/Uninfected")

# %%
#Transform and resize the all the images into the 75x75 matrices of pixels
import keras.preprocessing.image as im
picture = []
label = []

for infect in infected_cells :
  try :
    if infect != 'Thumbs.db':
      image = "/content/cell_images/Parasitized/"+infect
      img_array = im.img_to_array(im.load_img(image, target_size = (75,75), interpolation = 'nearest'), dtype = 'uint8')
      picture.append(np.array(img_array))
      label.append(1)

  except FileNotFoundError:
    continue

for uninfect in uninfected_cells :
  try :
    if uninfect != 'Thumbs.db':
      image = "/content/cell_images/Uninfected/"+uninfect
      img_array = im.img_to_array(im.load_img(image, target_size = (75,75), interpolation = 'nearest'), dtype = 'uint8')
      picture.append(np.array(img_array))
      label.append(0)

  except FileNotFoundError:
    continue

# %%
#Initialization of image data parameters
data = np.array(picture)
labels = np.array(label)

#Checks the total of rgb images array and the labels of them
np.save('data', data)
np.save('labels', labels)

print ('data : {}, labels : {}'.format(data.shape, labels.shape))
# Out:
# data : (27558, 75, 75, 3), labels : (27558,)

# %%
plt.imshow(data[3])

# %%
plt.figure(num = 1, figsize = (15,15))

for n in range (1,65) :
  val = np.random.randint(0, data.shape[0], 1)
  plt.subplot(8, 8, n)
  plt.subplots_adjust(wspace = 0.4, hspace = 0.4)
  plt.imshow(data[val[0]])
  plt.title('{} : {}'.format('Uninfected' if labels[val[0]] == 0 else 'Infected', labels[val[0]]))
  plt.yticks([])
  plt.xticks([])

plt.show()

# %%
#Normalizing the pixels array
data = data.astype('float32')
labels = labels.astype('int32')
data /= 255

# %%
#Data Randomization
arranger = np.random.shuffle(np.arange(data.shape[0]))
data = data[arranger]
labels = labels[arranger]

# %% [markdown]
# # **Data Preparation Conclusion**
#
#
# *   Images are transformed into 75x75 pixels matrix in feature 'data'
# *   Labels of the images (infected and uninfected) is determined in feature 'labels'
# *   The 'data' feature has already been normalized by dividing with 255 (black pixel value)
# *   All the dataset has been randomized

# %% [markdown]
# ## **Model Creation**
#
# 1.   List item
#
# 1.   List item
# 2.   List item
#
#
# 2.   List item
