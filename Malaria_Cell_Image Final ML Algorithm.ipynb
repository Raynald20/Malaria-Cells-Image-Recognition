# %% [markdown]
# <a href="https://colab.research.google.com/github/Raynald20/Malaria-Cells-Image-Recognition/blob/master/Malaria_Cell_Image%20Final%20ML%20Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **MALARIA CELLS IMAGE RECOGNITION**
#
# Classification of Malaria Cells Identification in Red Blood Cells Using Tensorflow

# %% [markdown]
# **Group Members:**
# 1. Raynald Masli
# 2. Syifa Nurul Fatimah

# %% [markdown]
# ## **Import Packages**

# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
import os
import cv2
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.initializers import Constant
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## **Download Data from Kaggle**

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a585b4d3-d5fe-468c-9d07-45371f53ee1e" name="files[]" multiple disabled />
#      <output id="result-a585b4d3-d5fe-468c-9d07-45371f53ee1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"raynaldmasli","key":"f0b16ad96cd92fe3c64f0b6430d2907b"}'}

# %%
# !ls -lha kaggle.json #Make sure that kaggle.json has already upload
# Out:
# -rw-r--r-- 1 root root 68 Apr  2 02:10 kaggle.json

# %%
# !pip install -q kaggle #kaggle library installation

# %%
#Access the Kaggle dataset for data input
# !mkdir -p~/.kaggle
# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list #Asking for Kaggle dataset
# Out:
# mkdir: invalid option -- '~'
# Try 'mkdir --help' for more information.
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.6 / client 1.5.4)
# ref                                                            title                                                size  lastUpdated          downloadCount
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# allen-institute-for-ai/CORD-19-research-challenge              COVID-19 Open Research Dataset Challenge (CORD-19)  729MB  2020-03-27 23:46:53          39290
# ryanxjhan/cbc-news-coronavirus-articles-march-26               CBC News Coronavirus/COVID-19 Articles (NLP)          6MB  2020-03-27 23:23:07             94
# danevans/world-bank-wdi-212-health-systems                     World Bank WDI 2.12 - Health Systems                  6KB  2020-03-29 19:00:14            106
# vitaliymalcev/russian-passenger-air-service-20072020           Russian passenger air service 2007-2020             114KB  2020-03-29 17:15:24             44
# sobhanmoosavi/us-accidents                                     US Accidents (3.0 million records)                  199MB  2020-01-17 04:45:09          11948
# fireballbyedimyrnmom/us-counties-covid-19-dataset              US counties COVID 19 dataset                        186KB  2020-04-01 20:08:24            270
# eswarchandt/amazon-music-reviews                               Amazon Musicual Instruments Reviews                   5MB  2020-03-29 02:59:52             46
# trtmio/project-coviewed-subreddit-coronavirus-news-corpus      Project COVIEWED Coronavirus News Corpus              8MB  2020-03-31 11:32:45              9
# monogenea/birdsongs-from-europe                                Bird songs from Europe (xeno-canto)                   7GB  2020-03-23 15:35:20             16
# dheerajmpai/hospitals-and-beds-in-india                        Hospitals and beds in India (Statewise)               5KB  2020-03-27 14:05:50            108
# lakritidis/identifying-influential-bloggers-techcrunch         Identifying Influential Bloggers: Techcrunch        112MB  2020-03-30 19:22:09             19
# bappekim/air-pollution-in-seoul                                Air Pollution in Seoul                               20MB  2020-03-29 07:42:23             80
# roche-data-science-coalition/uncover                           UNCOVER Challenge                                   154MB  2020-04-01 15:17:39              2
# sudalairajkumar/novel-corona-virus-2019-dataset                Novel Corona Virus 2019 Dataset                     636KB  2020-04-01 09:57:08         100503
# kimjihoo/coronavirusdataset                                    Data Science for COVID-19 (DS4C)                      3MB  2020-03-30 19:54:12          24025
# unanimad/dataisbeautiful                                       Reddit - Data is Beautiful                           11MB  2020-04-01 12:10:09           1418
# jessemostipak/hotel-booking-demand                             Hotel booking demand                                  1MB  2020-02-13 01:27:20          12044
# rubenssjr/brasilian-houses-to-rent                             brazilian_houses_to_rent                            282KB  2020-03-25 22:51:17           1497
# clmentbisaillon/fake-and-real-news-dataset                     Fake and real news dataset                           41MB  2020-03-26 18:51:15            536
# paultimothymooney/covid19-containment-and-mitigation-measures  COVID-19 containment and mitigation measures        216KB  2020-04-01 21:06:55           1156

# %%
# !kaggle datasets download -d iarunava/cell-images-for-detecting-malaria #malaria-cells-images download from Kaggle
# Out:
# Downloading cell-images-for-detecting-malaria.zip to /content
# 100% 675M/675M [00:09<00:00, 125MB/s]
# 100% 675M/675M [00:09<00:00, 75.1MB/s]

# %% [markdown]
# ## **Data Preparation**

# %%
import zipfile

#Extract the file from zip file
images = zipfile.ZipFile("/content/cell-images-for-detecting-malaria.zip", 'r')
images.extractall("/content")
images.close()

# %%
#Assign the images into either the infected cells and uninfected cells 

infected_cells = os.listdir("/content/cell_images/Parasitized")
uninfected_cells = os.listdir("/content/cell_images/Uninfected")

# %%
#Transform and resize the all the images into the 75x75 matrices of pixels
import keras.preprocessing.image as im
picture = []
label = []

for infect in infected_cells :
  try :
    if infect != 'Thumbs.db':
      image = "/content/cell_images/Parasitized/"+infect
      img_array = im.img_to_array(im.load_img(image, target_size = (75,75), interpolation = 'nearest'), dtype = 'uint8')
      picture.append(np.array(img_array))
      label.append(1)

  except FileNotFoundError:
    continue

for uninfect in uninfected_cells :
  try :
    if uninfect != 'Thumbs.db':
      image = "/content/cell_images/Uninfected/"+uninfect
      img_array = im.img_to_array(im.load_img(image, target_size = (75,75), interpolation = 'nearest'), dtype = 'uint8')
      picture.append(np.array(img_array))
      label.append(0)

  except FileNotFoundError:
    continue
# Out:
# Using TensorFlow backend.

# %%
#Initialization of image data parameters
data = np.array(picture)
labels = np.array(label)

#Checks the total of rgb images array and the labels of them
np.save('data', data)
np.save('labels', labels)

print ('data : {}, labels : {}'.format(data.shape, labels.shape))
# Out:
# data : (27558, 75, 75, 3), labels : (27558,)

# %%
plt.imshow(data[3])

# %%
plt.figure(num = 1, figsize = (15,15))

for n in range (1,65) :
  val = np.random.randint(0, data.shape[0], 1)
  plt.subplot(8, 8, n)
  plt.subplots_adjust(wspace = 0.4, hspace = 0.4)
  plt.imshow(data[val[0]])
  plt.title('{} : {}'.format('Uninfected' if labels[val[0]] == 0 else 'Infected', labels[val[0]]))
  plt.yticks([])
  plt.xticks([])

plt.show()

# %%
#Data Randomization
arranger = np.arange(data.shape[0])
np.random.shuffle(arranger)
data = data[arranger]
labels = labels[arranger]

# %% [markdown]
# # **Data Preparation Conclusion**
#
#
# *   Images are transformed into 75x75 pixels matrix in feature 'data'
# *   Labels of the images (infected and uninfected) is determined in feature 'labels'
# *   All the dataset has been randomized

# %% [markdown]
# ## **Model Creation**
#
# 1.   Training and testing dataset
#
# 2.   Build the model
#
# 2.   Model summary
#
# 3.   Compile the model
#
# 4.   Train and test the model
#
# 5.   Save the model
#
# 6.   Visualize training result

# %% [markdown]
# ### **Training and Tesing Dataset**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data, labels, test_size = 0.25)

# %%
plt.figure(1, figsize = (15,6), dpi = 80)
num_fig = 0

for pic, title in zip ([Y_train, Y_test], ['train labels', 'test labels']) :
  num_fig += 1
  plt.subplot(1, 3, num_fig)
  sb.countplot (x = pic)
  plt.title(title)

plt.show()

# %% [markdown]
# ### **Build the Model**

# %%
def Convmodel (filllayer, mode = 'relu'):
  model = Sequential()
  model.add(Conv2D(filllayer.pop(0), (3,3), input_shape = (75,75,3)))
  if mode == 'relu' : model.add(Activation('relu'))  
  elif mode == 'leakyrelu' : model.add(LeakyReLU())
  elif mode == 'prelu' : PReLU(Constant(value = 0.25))
  else : raise AttributeError(
      'mode only has 3 methods \'relu\', \'leakyrelu\',and \'prelu\'')

  for i,neurons in enumerate (filllayer):  
    model.add(Conv2D(neurons, (3,3), input_shape = (75,75,3)))
    if mode == 'relu' : model.add(Activation('relu'))  
    elif mode == 'leakyrelu' : model.add(LeakyReLU())
    elif mode == 'prelu' : PReLU(Constant(value = 0.25))
    else : raise AttributeError(
      'mode only has 3 methods \'relu\', \'leakyrelu\', and \'prelu\'')
    model.add(MaxPooling2D((2,2)))

  model.add(Flatten())
  model.add(Dense(512))
  if mode == 'relu' : model.add(Activation('relu'))  
  elif mode == 'leakyrelu' : model.add(LeakyReLU())
  elif mode == 'prelu' : PReLU(Constant(value = 0.25))
  else : raise AttributeError(
      'mode only has 3 methods \'relu\', \'leakyrelu\', and \'prelu\'')
  model.add(Dropout(0.5))
  model.add(Dense(64))
  if mode == 'relu' : model.add(Activation('relu'))  
  elif mode == 'leakyrelu' : model.add(LeakyReLU())
  elif mode == 'prelu' : PReLU(Constant(value = 0.25))
  else : raise AttributeError(
      'mode only has 3 methods \'relu\', \'leakyrelu\', and \'prelu\'')
  model.add(Dense(1, activation = 'sigmoid'))

  return model

# %% [markdown]
# ### **Model Summary**

# %%
model = Convmodel([32,64,128,256,512], mode = 'leakyrelu')
model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_100 (Conv2D)          (None, 73, 73, 32)        896
# _________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)   (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 71, 71, 64)        18496
# _________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)   (None, 71, 71, 64)        0
# _________________________________________________________________
# max_pooling2d_80 (MaxPooling (None, 35, 35, 64)        0
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 33, 33, 128)       73856
# _________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)   (None, 33, 33, 128)       0
# _________________________________________________________________
# max_pooling2d_81 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_103 (Conv2D)          (None, 14, 14, 256)       295168
# _________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)   (None, 14, 14, 256)       0
# _________________________________________________________________
# max_pooling2d_82 (MaxPooling (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_104 (Conv2D)          (None, 5, 5, 512)         1180160
# _________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)   (None, 5, 5, 512)         0
# _________________________________________________________________
# max_pooling2d_83 (MaxPooling (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_68 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 64)                32832
# _________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)   (None, 64)                0
# _________________________________________________________________
# dense_70 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 2,650,561
# Trainable params: 2,650,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Compile the Model**

# %%
model.compile(loss = 'binary_crossentropy', optimizer = optimizers.Adam(learning_rate = 0.001),
                   metrics=['accuracy'])

# %% [markdown]
# ### **Train and Test the Model**

# %%
batch_size = 32
epochs = 150
ntrain = len(X_train)
nval = len(X_test)

# %%
train_datagen = ImageDataGenerator(rescale = 1/225, horizontal_flip = True, vertical_flip = True, rotation_range = 30)

# %%
train_datagen = train_datagen.flow(X_train, Y_train, batch_size = batch_size)

# %%
history = model.fit_generator(train_datagen,
                              steps_per_epoch = ntrain // batch_size,
                              epochs = epochs)
# Out:
# Epoch 1/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.3306 - accuracy: 0.8627
# Epoch 2/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.2294 - accuracy: 0.9215
# Epoch 3/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.2150 - accuracy: 0.9271
# Epoch 4/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.2044 - accuracy: 0.9298
# Epoch 5/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1987 - accuracy: 0.9338
# Epoch 6/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1959 - accuracy: 0.9334
# Epoch 7/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1925 - accuracy: 0.9354
# Epoch 8/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1915 - accuracy: 0.9350
# Epoch 9/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1862 - accuracy: 0.9371
# Epoch 10/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1875 - accuracy: 0.9361
# Epoch 11/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1844 - accuracy: 0.9345
# Epoch 12/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1831 - accuracy: 0.9382
# Epoch 13/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1876 - accuracy: 0.9360
# Epoch 14/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1813 - accuracy: 0.9395
# Epoch 15/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1803 - accuracy: 0.9381
# Epoch 16/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1799 - accuracy: 0.9383
# Epoch 17/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1814 - accuracy: 0.9388
# Epoch 18/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1817 - accuracy: 0.9393
# Epoch 19/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1743 - accuracy: 0.9405
# Epoch 20/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1732 - accuracy: 0.9399
# Epoch 21/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1759 - accuracy: 0.9398
# Epoch 22/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1753 - accuracy: 0.9399
# Epoch 23/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1735 - accuracy: 0.9391
# Epoch 24/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1736 - accuracy: 0.9402
# Epoch 25/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1778 - accuracy: 0.9388
# Epoch 26/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1738 - accuracy: 0.9403
# Epoch 27/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1752 - accuracy: 0.9400
# Epoch 28/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1689 - accuracy: 0.9421
# Epoch 29/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1696 - accuracy: 0.9394
# Epoch 30/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1691 - accuracy: 0.9406
# Epoch 31/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1673 - accuracy: 0.9431
# Epoch 32/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1670 - accuracy: 0.9420
# Epoch 33/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1706 - accuracy: 0.9418
# Epoch 34/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1668 - accuracy: 0.9425
# Epoch 35/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1727 - accuracy: 0.9436
# Epoch 36/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1664 - accuracy: 0.9435
# Epoch 37/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1660 - accuracy: 0.9422
# Epoch 38/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1631 - accuracy: 0.9424
# Epoch 39/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1564 - accuracy: 0.9458
# Epoch 40/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1665 - accuracy: 0.9431
# Epoch 41/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1639 - accuracy: 0.9425
# Epoch 42/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1669 - accuracy: 0.9434
# Epoch 43/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1632 - accuracy: 0.9445
# Epoch 44/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1586 - accuracy: 0.9442
# Epoch 45/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1621 - accuracy: 0.9439
# Epoch 46/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1599 - accuracy: 0.9456
# Epoch 47/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1602 - accuracy: 0.9443
# Epoch 48/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1619 - accuracy: 0.9445
# Epoch 49/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1600 - accuracy: 0.9465
# Epoch 50/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1616 - accuracy: 0.9444
# Epoch 51/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1632 - accuracy: 0.9435
# Epoch 52/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1595 - accuracy: 0.9434
# Epoch 53/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1593 - accuracy: 0.9449
# Epoch 54/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1591 - accuracy: 0.9456
# Epoch 55/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1560 - accuracy: 0.9466
# Epoch 56/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1565 - accuracy: 0.9463
# Epoch 57/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1574 - accuracy: 0.9441
# Epoch 58/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1617 - accuracy: 0.9447
# Epoch 59/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1568 - accuracy: 0.9456
# Epoch 60/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1528 - accuracy: 0.9460
# Epoch 61/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1567 - accuracy: 0.9463
# Epoch 62/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1589 - accuracy: 0.9467
# Epoch 63/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1549 - accuracy: 0.9454
# Epoch 64/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1586 - accuracy: 0.9453
# Epoch 65/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1512 - accuracy: 0.9494
# Epoch 66/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1557 - accuracy: 0.9455
# Epoch 67/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1536 - accuracy: 0.9477
# Epoch 68/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1625 - accuracy: 0.9418
# Epoch 69/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1547 - accuracy: 0.9483
# Epoch 70/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1465 - accuracy: 0.9498
# Epoch 71/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1545 - accuracy: 0.9465
# Epoch 72/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1542 - accuracy: 0.9455
# Epoch 73/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1548 - accuracy: 0.9486
# Epoch 74/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1515 - accuracy: 0.9469
# Epoch 75/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1516 - accuracy: 0.9469
# Epoch 76/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1569 - accuracy: 0.9465
# Epoch 77/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1524 - accuracy: 0.9469
# Epoch 78/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1494 - accuracy: 0.9489
# Epoch 79/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1492 - accuracy: 0.9471
# Epoch 80/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1490 - accuracy: 0.9484
# Epoch 81/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1461 - accuracy: 0.9476
# Epoch 82/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1558 - accuracy: 0.9459
# Epoch 83/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1487 - accuracy: 0.9493
# Epoch 84/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1539 - accuracy: 0.9479
# Epoch 85/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1547 - accuracy: 0.9471
# Epoch 86/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1465 - accuracy: 0.9490
# Epoch 87/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1527 - accuracy: 0.9476
# Epoch 88/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1530 - accuracy: 0.9477
# Epoch 89/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1511 - accuracy: 0.9489
# Epoch 90/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1462 - accuracy: 0.9481
# Epoch 91/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1546 - accuracy: 0.9453
# Epoch 92/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1503 - accuracy: 0.9469
# Epoch 93/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1476 - accuracy: 0.9481
# Epoch 94/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1479 - accuracy: 0.9472
# Epoch 95/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1459 - accuracy: 0.9490
# Epoch 96/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1502 - accuracy: 0.9486
# Epoch 97/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1476 - accuracy: 0.9469
# Epoch 98/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1491 - accuracy: 0.9470
# Epoch 99/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1436 - accuracy: 0.9503
# Epoch 100/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1366 - accuracy: 0.9521
# Epoch 101/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1485 - accuracy: 0.9484
# Epoch 102/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1468 - accuracy: 0.9486
# Epoch 103/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1423 - accuracy: 0.9514
# Epoch 104/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1479 - accuracy: 0.9483
# Epoch 105/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1427 - accuracy: 0.9494
# Epoch 106/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1434 - accuracy: 0.9521
# Epoch 107/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1442 - accuracy: 0.9513
# Epoch 108/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1430 - accuracy: 0.9509
# Epoch 109/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1466 - accuracy: 0.9495
# Epoch 110/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1432 - accuracy: 0.9490
# Epoch 111/150
# 645/645 [==============================] - 31s 48ms/step - loss: 0.1434 - accuracy: 0.9513
# Epoch 112/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1472 - accuracy: 0.9498
# Epoch 113/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1452 - accuracy: 0.9506
# Epoch 114/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1420 - accuracy: 0.9501
# Epoch 115/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1474 - accuracy: 0.9501
# Epoch 116/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1482 - accuracy: 0.9484
# Epoch 117/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1453 - accuracy: 0.9497
# Epoch 118/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1443 - accuracy: 0.9524
# Epoch 119/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1385 - accuracy: 0.9526
# Epoch 120/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1474 - accuracy: 0.9477
# Epoch 121/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1397 - accuracy: 0.9509
# Epoch 122/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1458 - accuracy: 0.9505
# Epoch 123/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1373 - accuracy: 0.9523
# Epoch 124/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1349 - accuracy: 0.9538
# Epoch 125/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1408 - accuracy: 0.9518
# Epoch 126/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1397 - accuracy: 0.9512
# Epoch 127/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1429 - accuracy: 0.9515
# Epoch 128/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1402 - accuracy: 0.9520
# Epoch 129/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1415 - accuracy: 0.9508
# Epoch 130/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1464 - accuracy: 0.9504
# Epoch 131/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1355 - accuracy: 0.9517
# Epoch 132/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1406 - accuracy: 0.9493
# Epoch 133/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1372 - accuracy: 0.9516
# Epoch 134/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1356 - accuracy: 0.9522
# Epoch 135/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1424 - accuracy: 0.9501
# Epoch 136/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1391 - accuracy: 0.9515
# Epoch 137/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1474 - accuracy: 0.9485
# Epoch 138/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1367 - accuracy: 0.9524
# Epoch 139/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1343 - accuracy: 0.9533
# Epoch 140/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1444 - accuracy: 0.9505
# Epoch 141/150
# 645/645 [==============================] - 32s 50ms/step - loss: 0.1397 - accuracy: 0.9505
# Epoch 142/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1400 - accuracy: 0.9529
# Epoch 143/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1385 - accuracy: 0.9518
# Epoch 144/150
# 645/645 [==============================] - 31s 49ms/step - loss: 0.1470 - accuracy: 0.9501
# Epoch 145/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1362 - accuracy: 0.9515
# Epoch 146/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1371 - accuracy: 0.9510
# Epoch 147/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1343 - accuracy: 0.9531
# Epoch 148/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1402 - accuracy: 0.9517
# Epoch 149/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1399 - accuracy: 0.9522
# Epoch 150/150
# 645/645 [==============================] - 32s 49ms/step - loss: 0.1361 - accuracy: 0.9543

# %% [markdown]
# ### **Save the Model**

# %%
model.save_weights('model_weights.1')
model.save('model_keras.1')
# Out:
# INFO:tensorflow:Assets written to: model_keras.1/assets

# %% [markdown]
# ### **Visualize Training Result**

# %%
acc = history.history['accuracy']
loss = history.history['loss']

epochs_range = range(1, len(acc) + 1)
num_fig = 0

for met, col, ylab, title in zip ([acc, loss], ['red', 'green'], ['Accuracy', 'Loss'], ['Training Accuracy', 'Training Loss']):
  plt.figure(figsize = (15,5))
  num_fig += 1
  plt.subplot(1,2, num_fig)
  plt.plot(epochs_range, met, col)
  plt.title(title)
  plt.xlabel('Epochs')
  plt.ylabel(ylab)

plt.show()

# %%
import tensorflow.keras.metrics as mts
def conc_model(model):
  plt.figure(figsize = (5,5))
  y_pred = model.predict(X_test)
  y_pred = np.where(y_pred > 0.5, 1, 0)
  conf_matrix = np.array(tf.math.confusion_matrix(labels = Y_test, predictions = y_pred))
  acc = (conf_matrix[0,0] + conf_matrix[1,1])/(conf_matrix[0,0] + conf_matrix[1,1] + conf_matrix[1,0] + conf_matrix[0,1])*100
  prec = conf_matrix[1,1]/(conf_matrix[1,1] + conf_matrix[1,0])*100
  rec = conf_matrix[1,1]/(conf_matrix[1,1] + conf_matrix[0,1])*100
  f1_score = 2*prec*rec/(prec + rec)
  print('Test Accuracy = {:.2f}% \n Test Prediction = {:.2f}% \n Test Recall = {:.2f}% \n Test f1 Score = {:.2f}%'.format(acc, prec, rec, f1_score))
  sb.heatmap(conf_matrix, fmt = 'd', annot = True, square = True, cbar = False, cmap = 'Greens')
  plt.show()

conc_model(model)
# Out:
# Test Accuracy = 93.90%
#  Test Prediction = 92.31%
#  Test Recall = 95.35%
#  Test f1 Score = 93.81%

# %%
y_pred = model.predict(X_test)
y_pred = np.where(y_pred > 0.5, 1, 0)

plt.figure(num = 1, figsize = (20,20))

for n in range (1,65) :
  val = np.random.randint(0, X_test.shape[0], 1)
  plt.subplot(8, 8, n)
  plt.subplots_adjust(wspace = 0.5, hspace = 0.5)
  plt.imshow(X_test[val[0]])
  plt.title('True : {}; Predict : {}'.format(Y_test[val[0]], y_pred[val[0]]))
  plt.yticks([])
  plt.xticks([])

plt.show()
